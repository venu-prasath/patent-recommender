# %%
import pandas as pd
import json
import os
from selenium.webdriver import ChromeOptions
from selenium.webdriver.common.by import By
from selenium import webdriver
import csv
import re
from urllib.request import urlretrieve
import requests

# %%
dataset_folder = "./dataset"
if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)
    print("Dataset folder created")
else:
    print("Dataset folder already exists")
# Out:
# Dataset folder created

# %%
def saveToFile(content):
    file_dir = f"./dataset/{content['patent_id']}"
    if not os.path.exists(file_dir):
        os.makedirs(file_dir)
    file_path = f"./dataset/{content['patent_id']}/{content['patent_id']}.json"
    json_data = json.dumps(content, indent=4)
    with open(file_path, 'w') as json_file:
        json_file.write(json_data)
        print(f"File created for {content['patent_id']} at path: {file_path}")

# %%
global_classifications = []
def save_to_csv():
    global global_classifications
    with open('./scraper_list/classifiction_list.csv', 'a', newline = '') as result_file:
        wr = csv.writer(result_file, dialect='excel')
        for item in global_classifications:
            wr.writerow([item])

# %%
def scrape(patent_link):
    result = {}
    global global_classifications
    driver = webdriver.Chrome()
    driver.get(patent_link)
    driver.implicitly_wait(5)
    result['patent_link'] = patent_link

    #title, pubnum, abstract
    try:
        pubnum = driver.find_element(By.CSS_SELECTOR, "h2#pubnum")
        title = driver.find_element(By.CSS_SELECTOR, "h1#title")
        abstract = driver.find_element(By.CSS_SELECTOR, ".abstract.patent-text")
        result['patent_id'] = pubnum.text
        result['title'] = title.text
        result['abstract'] = abstract.text
    except: 
        result['patent_id'] = ''
        result['title'] = ''
        result['abstract'] = ''
    
    #Inventors and assignee
    try:
        people_div = driver.find_element(By.CSS_SELECTOR, ".important-people")
        inventors_st_mod = people_div.find_elements(By.CSS_SELECTOR, "state-modifier a")
        inventors = []
        for inventor in inventors_st_mod:
            inventors.append(inventor.text)
        result['inventors'] = inventors
    except:
        result['inventors'] = []

    try:
        assignee_element = driver.find_elements(By.CSS_SELECTOR, "dl.important-people dd")
        result['assignee'] = assignee_element[len(assignee_element)-1].text
    except:
        result['assignee'] = ""
    
    #classifications
    try:
        view_more_div = driver.find_element(By.CSS_SELECTOR, "classification-viewer div.more.classification-viewer")
        view_more_div.click()
        classifications = []
        classification_viewer = driver.find_element(By.CSS_SELECTOR, "classification-viewer.patent-result")
        a_tags = classification_viewer.find_elements(By.CSS_SELECTOR, "classification-tree.classification-viewer a")
        for a_tag in a_tags:
            if a_tag.text.strip():
                classifications.append(a_tag.text)
        result['classifications'] = classifications
        global_classifications = list(set(global_classifications + classifications))
    except:
        result['classifications'] = []

    try:
        abstract = driver.find_element(By.CSS_SELECTOR, ".abstract.patent-text")
        result['abstract'] = abstract.text
    except:
        result['abstract'] = ""
    try:
        claims_div = driver.find_element(By.CSS_SELECTOR, ".claims.patent-text")
        claims = claims_div.find_elements(By.CSS_SELECTOR, ".claim-text.patent-text")
        claims_text = ""
        for claim in claims:
            if re.match(r"[0-9]+.", claim.text):
                claims_text += "\n"+claim.text
        result['claims'] = claims_text
    except Exception:
        result['claims'] = ""
    try:
        app_tl_div = driver.find_element(By.CSS_SELECTOR, "application-timeline.patent-result > div.application-timeline")
        app_tl_children = app_tl_div.find_elements(By.CSS_SELECTOR, "div .event.layout.horizontal.application-timeline")
        for child in app_tl_children:
            split_child = child.text.split('\n')
            if split_child[0] == 'Status':
                result['status'] = split_child[1]
    except Exception:
        result['status'] = ""

    try:
        footer_div = driver.find_element(By.CSS_SELECTOR, "div.footer.patent-result")

        h3s_element = footer_div.find_elements(By.CSS_SELECTOR, "h3.patent-result")
        citations_idx = -1
        citedby_idx = -1
        for idx, h3 in enumerate(h3s_element):
            h3_text = h3.text
            if h3_text.startswith("Cited By"):
                citedby_idx = idx
            if h3_text.startswith("Patent Citations"):
                citations_idx = idx
        
        #print("C1, c2 => ", citations_idx, citedby_idx)

        pt_citations_element = footer_div.find_element(By.CSS_SELECTOR, "h3#patentCitations")
        pt_citations_text = pt_citations_element.text
        match = re.search(r'\((\d+)\)', pt_citations_text)
        total_citations = match.group(1)
        #print(total_citations, " - Total Citations")

        responsive_tbl_divs = footer_div.find_elements(By.CSS_SELECTOR, "div.responsive-table.patent-result")
        tr_divs = responsive_tbl_divs[citations_idx].find_elements(By.CSS_SELECTOR, "div.tr.patent-result")
        tr_divs = tr_divs[1:]
        citations_own = []
        own_citations_full = False
        citations_ftf = []
        for item in tr_divs:
            #print(item.text)
            patent_id = item.text.split(" ")[0]
            if patent_id == 'Family':
                own_citations_full = True
                continue
            if own_citations_full:
                citations_ftf.append(patent_id)
            else:
                citations_own.append(patent_id)

        #print(citations_own)
        #print(len(citations_own))
        #print(len(citations_ftf))
        result['citations_own'] = citations_own
        result['citations_ftf'] = citations_ftf

        pt_cited_by_element = footer_div.find_element(By.CSS_SELECTOR, "h3#citedBy")
        pt_citedby_text = pt_cited_by_element.text
        match = re.search(r'\((\d+)\)', pt_citedby_text)
        total_citedby = match.group(1)
        #print(total_citedby, " - Total Cited By")

        tr_divs = responsive_tbl_divs[citedby_idx].find_elements(By.CSS_SELECTOR, "div.tr.patent-result")
        tr_divs = tr_divs[1:]
        #print("length - ", len(tr_divs))
        citedby_own = []
        own_citedby_full = False
        citedby_ftf = []
        for item in tr_divs:
            #print(item.text)
            patent_id = item.text.split(" ")[0]
            if patent_id == 'Family':
                own_citedby_full = True
                continue
            if own_citedby_full:
                citedby_ftf.append(patent_id)
            else:
                citedby_own.append(patent_id)
        #print(len(citedby_own))
        #print(len(citedby_ftf))
        result['citedby_own'] = citedby_own
        result['citedby_ftf'] = citedby_ftf

    except Exception:
        result['citations_own'] = []
        result['citations_ftf'] = []
        result['citedby_own'] = []
        result['citedby_ftf'] = []
    return result

# %%
def test_selenium(url):
    driver = webdriver.Chrome()
    driver.get(url)
    driver.implicitly_wait(5) 
    pubnum = driver.find_element(By.CSS_SELECTOR, "h2#pubnum")
    title = driver.find_element(By.CSS_SELECTOR, "h1#title")
    abstract = driver.find_element(By.CSS_SELECTOR, ".abstract.patent-text")
    claims_div = driver.find_element(By.CSS_SELECTOR, ".claims.patent-text")
    claims = claims_div.find_elements(By.CSS_SELECTOR, ".claim-text.patent-text")
    print("Publication Number: ", pubnum.text)
    print("Title: ", title.text)
    print("Abstract: ", abstract.text)
    print("-----")
    #Inventors
    result = {}
    try:
        people_div = driver.find_element(By.CSS_SELECTOR, ".important-people")
        inventors_st_mod = people_div.find_elements(By.CSS_SELECTOR, "state-modifier a")
        inventors = []
        for inventor in inventors_st_mod:
            inventors.append(inventor.text)
        result['inventors'] = inventors
    except:
        result['inventors'] = []

    try:
        assignee_element = driver.find_elements(By.CSS_SELECTOR, "dl.important-people dd")
        result['assignee'] = assignee_element[len(assignee_element)-1].text
    except:
        result['assignee'] = ""

    print(result)
    print("--------")
#test_selenium()
#test_selenium("https://patents.google.com/patent/US20190378050A1/en?q=(machine+learning)&oq=machine+learning")

# %%
def scraper(patent_link):
    print(f"Fetching patent from: {patent_link}")
    result = scrape(patent_link)
    saveToFile(result)
    citations = []
    count = 0
    for citation in result['citations_own']:
        citation = citation.strip()
        if not citation.startswith("US"): continue
        patent_link = f"https://patents.google.com/patent/{citation}/en"
        citations.append(patent_link)
        count += 1
        if count == 10: break
    
    return citations

# %%
root_patent = "https://patents.google.com/patent/US20220253443A1/en"
root_patent_id = "US20220253443A1"

# %%
def save_citation_list(citations, filepath, mode):
    with open(filepath, mode) as file:
        for citation in citations:
            file.write(f"{citation}\n")
    
    print(f"{filepath}.txt file saved successfully")

# %%
def read_from_file(filepath):
    with open(filepath, 'r') as file:
        lines = file.readlines()

    lines = [line.strip() for line in lines]
    return lines

# %%
level_n_citations = []
n = 1

# %%
level_n_citations = scraper(root_patent)
# Out:
# Fetching patent from: https://patents.google.com/patent/US20220253443A1/en
# File created for US20220253443A1 at path: ./dataset/US20220253443A1/US20220253443A1.json

# %%
filepath = f"./scraper_list/level_{n}"
save_citation_list(level_n_citations, filepath, 'w')
# Out:
# ./scraper_list/level_1.txt file saved successfully

# %%
n = 4
filepath = f"./scraper_list/level_{n}"
level_n_citations = read_from_file(filepath)
print(f"Total citations to be parsed: {len(level_n_citations)}")
# Out:
# Total citations to be parsed: 720

# %%
citations = []
count = 1
for citation in level_n_citations:
    print(f"Fetching document: {count}")
    citation_list = scraper(citation)
    citations += list(set(citation_list))
    count += 1

n += 1
filepath = f"./scraper_list/level_{n}"
print(f"Saving citations for level {n} to {filepath}")
save_citation_list(citations, filepath, 'w')
# Out:
# Fetching document: 1
# Fetching patent from: https://patents.google.com/patent/US6085193A/en
# File created for US6085193A at path: ./dataset/US6085193A/US6085193A.json
# Fetching document: 2
# Fetching patent from: https://patents.google.com/patent/US6098096A/en
# File created for US6098096A at path: ./dataset/US6098096A/US6098096A.json
# Fetching document: 3
# Fetching patent from: https://patents.google.com/patent/US5924116A/en
# File created for US5924116A at path: ./dataset/US5924116A/US5924116A.json
# Fetching document: 4
# Fetching patent from: https://patents.google.com/patent/US5790935A/en
# File created for US5790935A at path: ./dataset/US5790935A/US5790935A.json
# Fetching document: 5
# Fetching patent from: https://patents.google.com/patent/US4996642A/en
# File created for US4996642A at path: ./dataset/US4996642A/US4996642A.json
# Fetching document: 6
# Fetching patent from: https://patents.google.com/patent/US5956039A/en
# File created for US5956039A at path: ./dataset/US5956039A/US5956039A.json
# Fetching document: 7
# Fetching patent from: https://patents.google.com/patent/US6016475A/en
# File created for US6016475A at path: ./dataset/US6016475A/US6016475A.json
# Fetching document: 8
# Fetching patent from: https://patents.google.com/patent/US6098064A/en
# File created for US6098064A at path: ./dataset/US6098064A/US6098064A.json
# Fetching document: 9
# Fetching patent from: https://patents.google.com/patent/US5842199A/en
# File created for US5842199A at path: ./dataset/US5842199A/US5842199A.json
# Fetching document: 10
# Fetching patent from: https://patents.google.com/patent/US5864854A/en
# File created for US5864854A at path: ./dataset/US5864854A/US5864854A.json
# Fetching document: 11
# Fetching patent from: https://patents.google.com/patent/US5701461A/en
# File created for US5701461A at path: ./dataset/US5701461A/US5701461A.json
# Fetching document: 12
# Fetching patent from: https://patents.google.com/patent/US5802292A/en
# File created for US5802292A at path: ./dataset/US5802292A/US5802292A.json
# Fetching document: 13
# Fetching patent from: https://patents.google.com/patent/US5721827A/en
# File created for US5721827A at path: ./dataset/US5721827A/US5721827A.json
# Fetching document: 14
# Fetching patent from: https://patents.google.com/patent/US5452447A/en
# File created for US5452447A at path: ./dataset/US5452447A/US5452447A.json
# Fetching document: 15
# Fetching patent from: https://patents.google.com/patent/US5329619A/en
# File created for US5329619A at path: ./dataset/US5329619A/US5329619A.json
# Fetching document: 16
# Fetching patent from: https://patents.google.com/patent/US5727065A/en
# File created for US5727065A at path: ./dataset/US5727065A/US5727065A.json
# Fetching document: 17
# Fetching patent from: https://patents.google.com/patent/US5737536A/en
# File created for US5737536A at path: ./dataset/US5737536A/US5737536A.json
# Fetching document: 18
# Fetching patent from: https://patents.google.com/patent/US5680573A/en
# File created for US5680573A at path: ./dataset/US5680573A/US5680573A.json
# Fetching document: 19
# Fetching patent from: https://patents.google.com/patent/US5940594A/en
# File created for US5940594A at path: ./dataset/US5940594A/US5940594A.json
# Fetching document: 20
# Fetching patent from: https://patents.google.com/patent/US5097428A/en
# File created for US5097428A at path: ./dataset/US5097428A/US5097428A.json
# Fetching document: 21
# Fetching patent from: https://patents.google.com/patent/US4653021A/en
# File created for US4653021A at path: ./dataset/US4653021A/US4653021A.json
# Fetching document: 22
# Fetching patent from: https://patents.google.com/patent/US5397893A/en
# File created for US5397893A at path: ./dataset/US5397893A/US5397893A.json
# Fetching document: 23
# Fetching patent from: https://patents.google.com/patent/US5033087A/en
# File created for US5033087A at path: ./dataset/US5033087A/US5033087A.json
# Fetching document: 24
# Fetching patent from: https://patents.google.com/patent/US5305219A/en
# File created for US5305219A at path: ./dataset/US5305219A/US5305219A.json
# Fetching document: 25
# Fetching patent from: https://patents.google.com/patent/US5168565A/en
# File created for US5168565A at path: ./dataset/US5168565A/US5168565A.json
# Fetching document: 26
# Fetching patent from: https://patents.google.com/patent/US5319509A/en
# File created for US5319509A at path: ./dataset/US5319509A/US5319509A.json
# Fetching document: 27
# Fetching patent from: https://patents.google.com/patent/US5287275A/en
# File created for US5287275A at path: ./dataset/US5287275A/US5287275A.json
# Fetching document: 28
# Fetching patent from: https://patents.google.com/patent/US5375244A/en
# File created for US5375244A at path: ./dataset/US5375244A/US5375244A.json
# Fetching document: 29
# Fetching patent from: https://patents.google.com/patent/US5227874A/en
# File created for US5227874A at path: ./dataset/US5227874A/US5227874A.json
# Fetching document: 30
# Fetching patent from: https://patents.google.com/patent/US6132969A/en
# File created for US6132969A at path: ./dataset/US6132969A/US6132969A.json
# Fetching document: 31
# Fetching patent from: https://patents.google.com/patent/US6594587B2/en
# File created for US6594587B2 at path: ./dataset/US6594587B2/US6594587B2.json
# Fetching document: 32
# Fetching patent from: https://patents.google.com/patent/US6772069B1/en
# File created for US6772069B1 at path: ./dataset/US6772069B1/US6772069B1.json
# Fetching document: 33
# Fetching patent from: https://patents.google.com/patent/US20020087275A1/en
# File created for US20020087275A1 at path: ./dataset/US20020087275A1/US20020087275A1.json
# Fetching document: 34
# Fetching patent from: https://patents.google.com/patent/US5604100A/en
# File created for US5604100A at path: ./dataset/US5604100A/US5604100A.json
# Fetching document: 35
# Fetching patent from: https://patents.google.com/patent/US6203987B1/en
# File created for US6203987B1 at path: ./dataset/US6203987B1/US6203987B1.json
# Fetching document: 36
# Fetching patent from: https://patents.google.com/patent/US5616504A/en
# File created for US5616504A at path: ./dataset/US5616504A/US5616504A.json
# Fetching document: 37
# Fetching patent from: https://patents.google.com/patent/US6154739A/en
# File created for US6154739A at path: ./dataset/US6154739A/US6154739A.json
# Fetching document: 38
# Fetching patent from: https://patents.google.com/patent/US6301579B1/en
# File created for US6301579B1 at path: ./dataset/US6301579B1/US6301579B1.json
# Fetching document: 39
# Fetching patent from: https://patents.google.com/patent/US6182133B1/en
# File created for US6182133B1 at path: ./dataset/US6182133B1/US6182133B1.json
# Fetching document: 40
# Fetching patent from: https://patents.google.com/patent/US5426780A/en
# File created for US5426780A at path: ./dataset/US5426780A/US5426780A.json
# Fetching document: 41
# Fetching patent from: https://patents.google.com/patent/US5299115A/en
# File created for US5299115A at path: ./dataset/US5299115A/US5299115A.json
# Fetching document: 42
# Fetching patent from: https://patents.google.com/patent/US5619709A/en
# File created for US5619709A at path: ./dataset/US5619709A/US5619709A.json
# Fetching document: 43
# Fetching patent from: https://patents.google.com/patent/US5459656A/en
# File created for US5459656A at path: ./dataset/US5459656A/US5459656A.json
# Fetching document: 44
# Fetching patent from: https://patents.google.com/patent/US5201010A/en
# File created for US5201010A at path: ./dataset/US5201010A/US5201010A.json
# Fetching document: 45
# Fetching patent from: https://patents.google.com/patent/US5642485A/en
# File created for US5642485A at path: ./dataset/US5642485A/US5642485A.json
# Fetching document: 46
# Fetching patent from: https://patents.google.com/patent/US4908761A/en
# File created for US4908761A at path: ./dataset/US4908761A/US4908761A.json
# Fetching document: 47
# Fetching patent from: https://patents.google.com/patent/US5675662A/en
# File created for US5675662A at path: ./dataset/US5675662A/US5675662A.json
# Fetching document: 48
# Fetching patent from: https://patents.google.com/patent/US5325298A/en
# File created for US5325298A at path: ./dataset/US5325298A/US5325298A.json
# Fetching document: 49
# Fetching patent from: https://patents.google.com/patent/US5389773A/en
# File created for US5389773A at path: ./dataset/US5389773A/US5389773A.json
# Fetching document: 50
# Fetching patent from: https://patents.google.com/patent/US5317507A/en
# File created for US5317507A at path: ./dataset/US5317507A/US5317507A.json
# Fetching document: 51
# Fetching patent from: https://patents.google.com/patent/US4802103A/en
# File created for US4802103A at path: ./dataset/US4802103A/US4802103A.json
# Fetching document: 52
# Fetching patent from: https://patents.google.com/patent/US4760604A/en
# File created for US4760604A at path: ./dataset/US4760604A/US4760604A.json
# Fetching document: 53
# Fetching patent from: https://patents.google.com/patent/US5052043A/en
# File created for US5052043A at path: ./dataset/US5052043A/US5052043A.json
# Fetching document: 54
# Fetching patent from: https://patents.google.com/patent/US5218646A/en
# File created for US5218646A at path: ./dataset/US5218646A/US5218646A.json
# Fetching document: 55
# Fetching patent from: https://patents.google.com/patent/US4805225A/en
# File created for US4805225A at path: ./dataset/US4805225A/US4805225A.json
# Fetching document: 56
# Fetching patent from: https://patents.google.com/patent/US5054094A/en
# File created for US5054094A at path: ./dataset/US5054094A/US5054094A.json
# Fetching document: 57
# Fetching patent from: https://patents.google.com/patent/US4761746A/en
# File created for US4761746A at path: ./dataset/US4761746A/US4761746A.json
# Fetching document: 58
# Fetching patent from: https://patents.google.com/patent/US5033006A/en
# File created for US5033006A at path: ./dataset/US5033006A/US5033006A.json
# Fetching document: 59
# Fetching patent from: https://patents.google.com/patent/US4807168A/en
# File created for US4807168A at path: ./dataset/US4807168A/US4807168A.json
# Fetching document: 60
# Fetching patent from: https://patents.google.com/patent/US5048097A/en
# File created for US5048097A at path: ./dataset/US5048097A/US5048097A.json
# Fetching document: 61
# Fetching patent from: https://patents.google.com/patent/US4731747A/en
# File created for US4731747A at path: ./dataset/US4731747A/US4731747A.json
# Fetching document: 62
# Fetching patent from: https://patents.google.com/patent/US4752906A/en
# File created for US4752906A at path: ./dataset/US4752906A/US4752906A.json
# Fetching document: 63
# Fetching patent from: https://patents.google.com/patent/US4760437A/en
# File created for US4760437A at path: ./dataset/US4760437A/US4760437A.json
# Fetching document: 64
# Fetching patent from: https://patents.google.com/patent/US4755963A/en
# File created for US4755963A at path: ./dataset/US4755963A/US4755963A.json
# Fetching document: 65
# Fetching patent from: https://patents.google.com/patent/US4660166A/en
# File created for US4660166A at path: ./dataset/US4660166A/US4660166A.json
# Fetching document: 66
# Fetching patent from: https://patents.google.com/patent/US4737929A/en
# File created for US4737929A at path: ./dataset/US4737929A/US4737929A.json
# Fetching document: 67
# Fetching patent from: https://patents.google.com/patent/US5987468A/en
# File created for US5987468A at path: ./dataset/US5987468A/US5987468A.json
# File created for US5617509A at path: ./dataset/US5617509A/US5617509A.json
# Fetching document: 90
# Fetching patent from: https://patents.google.com/patent/US5133012A/en
# File created for US5133012A at path: ./dataset/US5133012A/US5133012A.json
# Fetching document: 91
# Fetching patent from: https://patents.google.com/patent/US6321221B1/en
# File created for US6321221B1 at path: ./dataset/US6321221B1/US6321221B1.json
# Fetching document: 92
# Fetching patent from: https://patents.google.com/patent/US5974396A/en
# File created for US5974396A at path: ./dataset/US5974396A/US5974396A.json
# Fetching document: 93
# Fetching patent from: https://patents.google.com/patent/US6412012B1/en
# File created for US6412012B1 at path: ./dataset/US6412012B1/US6412012B1.json
# Fetching document: 94
# Fetching patent from: https://patents.google.com/patent/US6266649B1/en
# File created for US6266649B1 at path: ./dataset/US6266649B1/US6266649B1.json
# Fetching document: 95
# Fetching patent from: https://patents.google.com/patent/US20020055906A1/en
# File created for US20020055906A1 at path: ./dataset/US20020055906A1/US20020055906A1.json
# Fetching document: 96
# Fetching patent from: https://patents.google.com/patent/US6317722B1/en
# File created for US6317722B1 at path: ./dataset/US6317722B1/US6317722B1.json
# Fetching document: 97
# Fetching patent from: https://patents.google.com/patent/US6334127B1/en
# File created for US6334127B1 at path: ./dataset/US6334127B1/US6334127B1.json
# Fetching document: 98
# Fetching patent from: https://patents.google.com/patent/US20020112249A1/en
# File created for US20020112249A1 at path: ./dataset/US20020112249A1/US20020112249A1.json
# Fetching document: 99
# Fetching patent from: https://patents.google.com/patent/US5671351A/en
# File created for US5671351A at path: ./dataset/US5671351A/US5671351A.json
# Fetching document: 100
# Fetching patent from: https://patents.google.com/patent/US6006225A/en
# File created for US6006225A at path: ./dataset/US6006225A/US6006225A.json
# Fetching document: 101
# Fetching patent from: https://patents.google.com/patent/US20040006457A1/en
# File created for US20040006457A1 at path: ./dataset/US20040006457A1/US20040006457A1.json
# Fetching document: 102
# Fetching patent from: https://patents.google.com/patent/US20020099730A1/en
# File created for US20020099730A1 at path: ./dataset/US20020099730A1/US20020099730A1.json
# Fetching document: 103
# Fetching patent from: https://patents.google.com/patent/US20040205461A1/en
# File created for US20040205461A1 at path: ./dataset/US20040205461A1/US20040205461A1.json
# Fetching document: 104
# Fetching patent from: https://patents.google.com/patent/US20040107102A1/en
# File created for US20040107102A1 at path: ./dataset/US20040107102A1/US20040107102A1.json
# Fetching document: 105
# Fetching patent from: https://patents.google.com/patent/US6493702B1/en
# File created for US6493702B1 at path: ./dataset/US6493702B1/US6493702B1.json
# Fetching document: 106
# Fetching patent from: https://patents.google.com/patent/US20050022106A1/en
# File created for US20050022106A1 at path: ./dataset/US20050022106A1/US20050022106A1.json
# Fetching document: 107
# Fetching patent from: https://patents.google.com/patent/US6014663A/en
# File created for US6014663A at path: ./dataset/US6014663A/US6014663A.json
# Fetching document: 108
# Fetching patent from: https://patents.google.com/patent/US20030028566A1/en
# File created for US20030028566A1 at path: ./dataset/US20030028566A1/US20030028566A1.json
# Fetching document: 109
# Fetching patent from: https://patents.google.com/patent/US6094632A/en
# File created for US6094632A at path: ./dataset/US6094632A/US6094632A.json
# Fetching document: 110
# Fetching patent from: https://patents.google.com/patent/US20040218838A1/en
# File created for US20040218838A1 at path: ./dataset/US20040218838A1/US20040218838A1.json
# Fetching document: 111
# Fetching patent from: https://patents.google.com/patent/US4567560A/en
# File created for US4567560A at path: ./dataset/US4567560A/US4567560A.json
# Fetching document: 112
# Fetching patent from: https://patents.google.com/patent/US4561093A/en
# File created for US4561093A at path: ./dataset/US4561093A/US4561093A.json
# Fetching document: 113
# Fetching patent from: https://patents.google.com/patent/US3862404A/en
# File created for US3862404A at path: ./dataset/US3862404A/US3862404A.json
# Fetching document: 114
# Fetching patent from: https://patents.google.com/patent/US3906205A/en
# File created for US3906205A at path: ./dataset/US3906205A/US3906205A.json
# Fetching document: 115
# Fetching patent from: https://patents.google.com/patent/US4026251A/en
# File created for US4026251A at path: ./dataset/US4026251A/US4026251A.json
# Fetching document: 116
# Fetching patent from: https://patents.google.com/patent/US3816717A/en
# File created for US3816717A at path: ./dataset/US3816717A/US3816717A.json
# Fetching document: 117
# Fetching patent from: https://patents.google.com/patent/US3969614A/en
# File created for US3969614A at path: ./dataset/US3969614A/US3969614A.json
# Fetching document: 118
# Fetching patent from: https://patents.google.com/patent/US3888220A/en
# File created for US3888220A at path: ./dataset/US3888220A/US3888220A.json
# Fetching document: 119
# Fetching patent from: https://patents.google.com/patent/US3916170A/en
# File created for US3916170A at path: ./dataset/US3916170A/US3916170A.json
# Fetching document: 120
# Fetching patent from: https://patents.google.com/patent/US4038526A/en
# File created for US4038526A at path: ./dataset/US4038526A/US4038526A.json
# Fetching document: 121
# Fetching patent from: https://patents.google.com/patent/US3846760A/en
# File created for US3846760A at path: ./dataset/US3846760A/US3846760A.json
# Fetching document: 122
# Fetching patent from: https://patents.google.com/patent/US3835819A/en
# File created for US3835819A at path: ./dataset/US3835819A/US3835819A.json
# Fetching document: 123
# Fetching patent from: https://patents.google.com/patent/US4459259A/en
# File created for US4459259A at path: ./dataset/US4459259A/US4459259A.json
# Fetching document: 124
# Fetching patent from: https://patents.google.com/patent/US4472770A/en
# File created for US4472770A at path: ./dataset/US4472770A/US4472770A.json
# Fetching document: 125
# Fetching patent from: https://patents.google.com/patent/US4595982A/en
# File created for US4595982A at path: ./dataset/US4595982A/US4595982A.json
# Fetching document: 126
# Fetching patent from: https://patents.google.com/patent/US4591983A/en
# File created for US4591983A at path: ./dataset/US4591983A/US4591983A.json
# Fetching document: 127
# Fetching patent from: https://patents.google.com/patent/US4628435A/en
# File created for US4628435A at path: ./dataset/US4628435A/US4628435A.json
# Fetching document: 128
# Fetching patent from: https://patents.google.com/patent/US4563735A/en
# File created for US4563735A at path: ./dataset/US4563735A/US4563735A.json
# Fetching document: 129
# Fetching patent from: https://patents.google.com/patent/US4328556A/en
# File created for US4328556A at path: ./dataset/US4328556A/US4328556A.json
# Fetching document: 130
# Fetching patent from: https://patents.google.com/patent/US4349869A/en
# File created for US4349869A at path: ./dataset/US4349869A/US4349869A.json
# Fetching document: 131
# Fetching patent from: https://patents.google.com/patent/US4458321A/en
# File created for US4458321A at path: ./dataset/US4458321A/US4458321A.json
# Fetching document: 132
# Fetching patent from: https://patents.google.com/patent/US4517468A/en
# File created for US4517468A at path: ./dataset/US4517468A/US4517468A.json
# Fetching document: 133
# Fetching patent from: https://patents.google.com/patent/US4220993A/en
# File created for US4220993A at path: ./dataset/US4220993A/US4220993A.json
# Fetching document: 134
# Fetching patent from: https://patents.google.com/patent/US3852956A/en
# File created for US3852956A at path: ./dataset/US3852956A/US3852956A.json
# Fetching document: 135
# Fetching patent from: https://patents.google.com/patent/US4276744A/en
# File created for US4276744A at path: ./dataset/US4276744A/US4276744A.json
# Fetching document: 136
# Fetching patent from: https://patents.google.com/patent/US4594849A/en
# File created for US4594849A at path: ./dataset/US4594849A/US4594849A.json
# Fetching document: 137
# Fetching patent from: https://patents.google.com/patent/US3987620A/en
# File created for US3987620A at path: ./dataset/US3987620A/US3987620A.json
# Fetching document: 138
# Fetching patent from: https://patents.google.com/patent/US4188781A/en
# File created for US4188781A at path: ./dataset/US4188781A/US4188781A.json
# Fetching document: 139
# Fetching patent from: https://patents.google.com/patent/US4411595A/en
# File created for US4411595A at path: ./dataset/US4411595A/US4411595A.json
# Fetching document: 140
# Fetching patent from: https://patents.google.com/patent/US4275557A/en
# File created for US4275557A at path: ./dataset/US4275557A/US4275557A.json
# Fetching document: 141
# Fetching patent from: https://patents.google.com/patent/US4625510A/en
# File created for US4625510A at path: ./dataset/US4625510A/US4625510A.json
# Fetching document: 142
# Fetching patent from: https://patents.google.com/patent/US3882672A/en
# File created for US3882672A at path: ./dataset/US3882672A/US3882672A.json
# Fetching document: 143
# Fetching patent from: https://patents.google.com/patent/US3701974A/en
# File created for US3701974A at path: ./dataset/US3701974A/US3701974A.json
# Fetching document: 144
# Fetching patent from: https://patents.google.com/patent/US3579191A/en
# File created for US3579191A at path: ./dataset/US3579191A/US3579191A.json
# Fetching document: 145
# Fetching patent from: https://patents.google.com/patent/US3950733A/en
# File created for US3950733A at path: ./dataset/US3950733A/US3950733A.json
# Fetching document: 146
# Fetching patent from: https://patents.google.com/patent/US4731747A/en
# File created for US4731747A at path: ./dataset/US4731747A/US4731747A.json
# Fetching document: 147
# Fetching patent from: https://patents.google.com/patent/US4193115A/en
# File created for US4193115A at path: ./dataset/US4193115A/US4193115A.json
# Fetching document: 148
# Fetching patent from: https://patents.google.com/patent/US4660166A/en
# File created for US4660166A at path: ./dataset/US4660166A/US4660166A.json
# Fetching document: 149
# Fetching patent from: https://patents.google.com/patent/US3484749A/en
# File created for  at path: ./dataset//.json
# Fetching document: 150
# Fetching patent from: https://patents.google.com/patent/US3273125A/en
# File created for  at path: ./dataset//.json
# Fetching document: 151
# Fetching patent from: https://patents.google.com/patent/US4419731A/en
# File created for US4419731A at path: ./dataset/US4419731A/US4419731A.json
# File created for US6122634A at path: ./dataset/US6122634A/US6122634A.json
# Fetching document: 255
# Fetching patent from: https://patents.google.com/patent/US5974412A/en
# File created for US5974412A at path: ./dataset/US5974412A/US5974412A.json
# Fetching document: 256
# Fetching patent from: https://patents.google.com/patent/US5754939A/en
# File created for US5754939A at path: ./dataset/US5754939A/US5754939A.json
# Fetching document: 257
# Fetching patent from: https://patents.google.com/patent/US5418948A/en
# File created for US5418948A at path: ./dataset/US5418948A/US5418948A.json
# Fetching document: 258
# Fetching patent from: https://patents.google.com/patent/US6038574A/en
# File created for US6038574A at path: ./dataset/US6038574A/US6038574A.json
# Fetching document: 259
# Fetching patent from: https://patents.google.com/patent/US6028601A/en
# File created for US6028601A at path: ./dataset/US6028601A/US6028601A.json
# Fetching document: 260
# Fetching patent from: https://patents.google.com/patent/US6078916A/en
# File created for US6078916A at path: ./dataset/US6078916A/US6078916A.json
# Fetching document: 261
# Fetching patent from: https://patents.google.com/patent/US5668988A/en
# File created for US5668988A at path: ./dataset/US5668988A/US5668988A.json
# Fetching document: 262
# Fetching patent from: https://patents.google.com/patent/US6038560A/en
# File created for US6038560A at path: ./dataset/US6038560A/US6038560A.json
# Fetching document: 263
# Fetching patent from: https://patents.google.com/patent/US6098064A/en
# File created for US6098064A at path: ./dataset/US6098064A/US6098064A.json
# Fetching document: 264
# Fetching patent from: https://patents.google.com/patent/US6067552A/en
# File created for US6067552A at path: ./dataset/US6067552A/US6067552A.json
# Fetching document: 265
# Fetching patent from: https://patents.google.com/patent/US20060064017A1/en
# File created for US20060064017A1 at path: ./dataset/US20060064017A1/US20060064017A1.json
# Fetching document: 266
# Fetching patent from: https://patents.google.com/patent/US6058205A/en
# File created for US6058205A at path: ./dataset/US6058205A/US6058205A.json
# Fetching document: 267
# Fetching patent from: https://patents.google.com/patent/US7453472B2/en
# File created for US7453472B2 at path: ./dataset/US7453472B2/US7453472B2.json
# Fetching document: 268
# Fetching patent from: https://patents.google.com/patent/US20070053563A1/en
# File created for US20070053563A1 at path: ./dataset/US20070053563A1/US20070053563A1.json
# Fetching document: 269
# Fetching patent from: https://patents.google.com/patent/US20080087561A1/en
# File created for US20080087561A1 at path: ./dataset/US20080087561A1/US20080087561A1.json
# Fetching document: 270
# Fetching patent from: https://patents.google.com/patent/US20070055153A1/en
# File created for US20070055153A1 at path: ./dataset/US20070055153A1/US20070055153A1.json
# Fetching document: 271
# Fetching patent from: https://patents.google.com/patent/US20080075367A1/en
# File created for US20080075367A1 at path: ./dataset/US20080075367A1/US20080075367A1.json
# Fetching document: 272
# Fetching patent from: https://patents.google.com/patent/US20080317331A1/en
# File created for US20080317331A1 at path: ./dataset/US20080317331A1/US20080317331A1.json
# Fetching document: 273
# Fetching patent from: https://patents.google.com/patent/US7451123B2/en
# File created for US7451123B2 at path: ./dataset/US7451123B2/US7451123B2.json
# Fetching document: 274
# Fetching patent from: https://patents.google.com/patent/US20050010445A1/en
# File created for US20050010445A1 at path: ./dataset/US20050010445A1/US20050010445A1.json
# Fetching document: 275
# Fetching patent from: https://patents.google.com/patent/US20060047616A1/en
# File created for US20060047616A1 at path: ./dataset/US20060047616A1/US20060047616A1.json
# Fetching document: 276
# Fetching patent from: https://patents.google.com/patent/US7177675B2/en
# File created for US7177675B2 at path: ./dataset/US7177675B2/US7177675B2.json
# Fetching document: 277
# Fetching patent from: https://patents.google.com/patent/US6622036B1/en
# File created for US6622036B1 at path: ./dataset/US6622036B1/US6622036B1.json
# Fetching document: 278
# Fetching patent from: https://patents.google.com/patent/US7231245B2/en
# File created for US7231245B2 at path: ./dataset/US7231245B2/US7231245B2.json
# Fetching document: 279
# Fetching patent from: https://patents.google.com/patent/US6714925B1/en
# File created for US6714925B1 at path: ./dataset/US6714925B1/US6714925B1.json
# Fetching document: 280
# Fetching patent from: https://patents.google.com/patent/US6063028A/en
# File created for US6063028A at path: ./dataset/US6063028A/US6063028A.json
# Fetching document: 281
# Fetching patent from: https://patents.google.com/patent/US6463321B2/en
# File created for US6463321B2 at path: ./dataset/US6463321B2/US6463321B2.json
# Fetching document: 282
# Fetching patent from: https://patents.google.com/patent/US20060064415A1/en
# File created for US20060064415A1 at path: ./dataset/US20060064415A1/US20060064415A1.json
# Fetching document: 283
# Fetching patent from: https://patents.google.com/patent/US20020143563A1/en
# ...
# Fetching document: 630
# Fetching patent from: https://patents.google.com/patent/US6327345B1/en
# File created for US6327345B1 at path: ./dataset/US6327345B1/US6327345B1.json
# Fetching document: 631
# Fetching patent from: https://patents.google.com/patent/US6157707A/en
# File created for US6157707A at path: ./dataset/US6157707A/US6157707A.json
# Fetching document: 632
# Fetching patent from: https://patents.google.com/patent/US20090132335A1/en
# File created for US20090132335A1 at path: ./dataset/US20090132335A1/US20090132335A1.json
# Fetching document: 633
# Fetching patent from: https://patents.google.com/patent/US20040254876A1/en
# File created for US20040254876A1 at path: ./dataset/US20040254876A1/US20040254876A1.json
# Fetching document: 634
# Fetching patent from: https://patents.google.com/patent/US20080243572A1/en
# File created for US20080243572A1 at path: ./dataset/US20080243572A1/US20080243572A1.json
# Fetching document: 635
# Fetching patent from: https://patents.google.com/patent/US7774257B2/en
# File created for US7774257B2 at path: ./dataset/US7774257B2/US7774257B2.json
# Fetching document: 636
# Fetching patent from: https://patents.google.com/patent/US20110060677A1/en
# File created for US20110060677A1 at path: ./dataset/US20110060677A1/US20110060677A1.json
# Fetching document: 637
# Fetching patent from: https://patents.google.com/patent/US20040064395A1/en
# File created for US20040064395A1 at path: ./dataset/US20040064395A1/US20040064395A1.json
# Fetching document: 638
# Fetching patent from: https://patents.google.com/patent/US20070203783A1/en
# File created for US20070203783A1 at path: ./dataset/US20070203783A1/US20070203783A1.json
# Fetching document: 639
# Fetching patent from: https://patents.google.com/patent/US20080027880A1/en
# File created for US20080027880A1 at path: ./dataset/US20080027880A1/US20080027880A1.json
# Fetching document: 640
# Fetching patent from: https://patents.google.com/patent/US7958043B2/en
# Fetching document: 681
# Fetching patent from: https://patents.google.com/patent/US3303896A/en
# File created for  at path: ./dataset//.json
# Fetching document: 682
# Fetching patent from: https://patents.google.com/patent/US3960736A/en
# File created for US3960736A at path: ./dataset/US3960736A/US3960736A.json
# Fetching document: 683
# Fetching patent from: https://patents.google.com/patent/US3565176A/en
# File created for US3565176A at path: ./dataset/US3565176A/US3565176A.json
# Fetching document: 684
# Fetching patent from: https://patents.google.com/patent/US3937283A/en
# File created for US3937283A at path: ./dataset/US3937283A/US3937283A.json
# Fetching document: 685
# Fetching patent from: https://patents.google.com/patent/US3301848A/en
# File created for  at path: ./dataset//.json
# Fetching document: 686
# Fetching patent from: https://patents.google.com/patent/US3933205A/en
# File created for US3933205A at path: ./dataset/US3933205A/US3933205A.json
# Fetching document: 687
# Fetching patent from: https://patents.google.com/patent/US20100218231A1/en
# File created for US20100218231A1 at path: ./dataset/US20100218231A1/US20100218231A1.json
# Fetching document: 688
# Fetching patent from: https://patents.google.com/patent/US20080170551A1/en
# File created for US20080170551A1 at path: ./dataset/US20080170551A1/US20080170551A1.json
# Fetching document: 689
# Fetching patent from: https://patents.google.com/patent/US20070280298A1/en
# File created for US20070280298A1 at path: ./dataset/US20070280298A1/US20070280298A1.json
# Fetching document: 690
# Fetching patent from: https://patents.google.com/patent/US20030220100A1/en
# File created for US20030220100A1 at path: ./dataset/US20030220100A1/US20030220100A1.json
# Fetching document: 691
# Fetching patent from: https://patents.google.com/patent/US20090086643A1/en
# File created for US20090086643A1 at path: ./dataset/US20090086643A1/US20090086643A1.json
# Fetching document: 692
# Fetching patent from: https://patents.google.com/patent/US5675581A/en
# File created for US5675581A at path: ./dataset/US5675581A/US5675581A.json
# Fetching document: 693
# Fetching patent from: https://patents.google.com/patent/US6327274B1/en
# File created for US6327274B1 at path: ./dataset/US6327274B1/US6327274B1.json
# Fetching document: 694
# Fetching patent from: https://patents.google.com/patent/US6112323A/en
# File created for US6112323A at path: ./dataset/US6112323A/US6112323A.json
# Fetching document: 695
# Fetching patent from: https://patents.google.com/patent/US6678268B1/en
# File created for US6678268B1 at path: ./dataset/US6678268B1/US6678268B1.json
# Fetching document: 696
# Fetching patent from: https://patents.google.com/patent/US6714898B1/en
# File created for US6714898B1 at path: ./dataset/US6714898B1/US6714898B1.json
# Fetching document: 697
# Fetching patent from: https://patents.google.com/patent/US6377579B1/en
# File created for US6377579B1 at path: ./dataset/US6377579B1/US6377579B1.json
# Fetching document: 698
# Fetching patent from: https://patents.google.com/patent/US5477531A/en
# File created for US5477531A at path: ./dataset/US5477531A/US5477531A.json
# Fetching document: 699
# Fetching patent from: https://patents.google.com/patent/US20010043586A1/en
# File created for US20010043586A1 at path: ./dataset/US20010043586A1/US20010043586A1.json
# Fetching document: 700
# Fetching patent from: https://patents.google.com/patent/US6308072B1/en
# File created for US6308072B1 at path: ./dataset/US6308072B1/US6308072B1.json
# Fetching document: 701
# Fetching patent from: https://patents.google.com/patent/US6975656B1/en
